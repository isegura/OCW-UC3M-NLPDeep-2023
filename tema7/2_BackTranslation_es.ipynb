# %% [markdown]
# <center>
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/47/Acronimo_y_nombre_uc3m.png"/>
#
# <img src="https://mirrors.creativecommons.org/presskit/buttons/88x31/png/by-nc-sa.png" width=15%/>
# </center>

# %% [markdown]
# # Back translation
#
# La idea básica de este método es traducir el texto de entrada a un idioma, y volver a traducirlo al idioma original. De esta forma, podemos generar un nuevo texto con diferentes palabras conservando el significado del texto original. Para hacer esto, podemos usar diferentes API de traducción de idiomas como google translate, Bing, Yandex.
#
# <center>
# <figure>
# <img src="https://lh6.googleusercontent.com/x3ZAhTDLT1QVSD8gCdaBVMquM2dcYA15A-orfzXyTzhTP8m0ZKLXz_2NrJdWlTgWKRS7BimExM8RO9Ce_uVVVdRR29vGeP0VZdncDZY0GTwkctocQyYg7HK9VL5ay3QC4JhbSXBK">
#
# <figcaption>Amit Chaudhary “Back Translation for Text Augmentation with Google Sheets”</figcaption>
# </figure>
# </center>
#
# En la imagen anterior, podemos ver que la oración original y generada tienen el mismo significado.

# %% [markdown]
# Veamos cómo implementar este método. Vamos a usar la librería **translators**, cuyo objetivo es brindar una traducción gratuita, múltiple y agradable para las personas en Python.
#
# Se basa en la interfaz de traducción de Google, Yandex, Microsoft(Bing), Baidu, Alibaba, Tencent, NetEase(Youdao), Sogou, Kingsoft(Iciba), Iflytek, Niutrans, Lingvanex, Naver(Papago), Deepl, Reverso, Itranslate , Caiyun, TranslateCom, Mglip, Utibet, Argos, etc.

# %%
# !pip install translators
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting translators
#   Downloading translators-5.6.3-py3-none-any.whl (36 kB)
# Requirement already satisfied: cryptography>=38.0.1 in /usr/local/lib/python3.9/dist-packages (from translators) (39.0.2)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from translators) (4.9.2)
# Collecting pathos>=0.2.9
#   Downloading pathos-0.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 KB 3.3 MB/s eta 0:00:00
# Collecting requests>=2.28.1
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.9/dist-packages (from translators) (4.65.0)
# Collecting PyExecJS>=1.5.1
#   Downloading PyExecJS-1.5.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=38.0.1->translators) (1.15.1)
# Collecting dill>=0.3.6
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 5.8 MB/s eta 0:00:00
# Collecting multiprocess>=0.70.14
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 8.0 MB/s eta 0:00:00
# Collecting pox>=0.3.2
#   Downloading pox-0.3.2-py3-none-any.whl (29 kB)
# Collecting ppft>=1.7.6.6
#   Downloading ppft-1.7.6.6-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from PyExecJS>=1.5.1->translators) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28.1->translators) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28.1->translators) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28.1->translators) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28.1->translators) (2022.12.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=38.0.1->translators) (2.21)
# Building wheels for collected packages: PyExecJS
#   Building wheel for PyExecJS (setup.py) ... done
#   Created wheel for PyExecJS: filename=PyExecJS-1.5.1-py3-none-any.whl size=14597 sha256=2c007059ed968e3111e2fa3f97f4425274b566e0b8d5325eb0f24d02c393c8c7
#   Stored in directory: /root/.cache/pip/wheels/5b/ac/94/92a4835bff6f53c3faa26411e9db1a879d6e662c75b18a9603
# Successfully built PyExecJS
# Installing collected packages: requests, PyExecJS, ppft, pox, dill, multiprocess, pathos, translators
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# Successfully installed PyExecJS-1.5.1 dill-0.3.6 multiprocess-0.70.14 pathos-0.3.0 pox-0.3.2 ppft-1.7.6.6 requests-2.28.2 translators-5.6.3

# %% [markdown]
# In the following cell, we will implement some functions to generate new sentences by using back translation:

# %%
import pandas as pd
# current version have logs, which is not very comfortable
import translators as ts
from multiprocessing import Pool
from tqdm import *
import pandas as pd
# current version have logs, which is not very comfortable
import translators as ts
from multiprocessing import Pool
from tqdm import *

LANG = 'en'
API = 'bing'


def translator_constructor(api):
    """This function calls to a particular API translation to be used and returns
    the object trasnlator created"""
    if api == 'google':
        return ts.google
    elif api == 'bing':
        return ts.bing
    elif api == 'baidu':
        return ts.baidu
    elif api == 'sogou':
        return ts.sogou
    elif api == 'youdao':
        return ts.youdao
    elif api == 'tencent':
        return ts.tencent
    elif api == 'alibaba':
        return ts.alibaba
    else:
        raise NotImplementedError(f'{api} translator is not realised!')


def translate(x):
    """This function gests an instance whose first field is a text and the second one its language.
    Then, it returns the original text and its translation to LANG"""
    text = x[0]
    lang = x[1]
    print(' lang: ' +  lang + ' LANG:' + LANG)

    try:
        translator = translator_constructor(API)
        try:
            # translate the text from lang to LANG
            new_text = translator(text, lang, LANG)
        except:
            new_text = text

        # again, we translate the text from LANG to lang
        new_text = translator(new_text, LANG, lang)
        return [text, new_text]

    except:
        return [text, None]


def imap_unordered_bar(func, args, n_processes: int = 48):
    """This funtion allows to parallelize the execution of a function, func, on a
    dataframe args"""

    p = Pool(n_processes, maxtasksperchild=100)
    res_list = []
    with tqdm(total=len(args)) as pbar:
        for i, res in tqdm(enumerate(p.imap_unordered(func, args))):
            pbar.update()
            res_list.append(res)
    pbar.close()
    p.close()
    p.join()
    return res_list

# %% [markdown]
# Vamos a usarlo sobre un dataset que contiene oraciones de diferentes idiomas (https://www.kaggle.com/competitions/jigsaw-multilingual-toxic-comment-classification/data). (Solo cargamos una pequeña muestra).

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
path = "/content/drive/My Drive/Colab Notebooks/data/toxic/sample_jigsaw_toxic.csv"

df = pd.read_csv(path) 

print('dataset was loaded ', df.shape)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# dataset was loaded  (51, 4)
#    id                                       comment_text lang  toxic
# 0   0  Este usuario ni siquiera llega al rango de    ...   es      0
# 1   1  Il testo di questa voce pare esser scopiazzato...   it      0
# 2   2  Vale. Sólo expongo mi pasado. Todo tiempo pasa...   es      1
# 3   3  Bu maddenin alt başlığı olarak  uluslararası i...   tr      0
# 4   4  Belçika nın şehirlerinin yanında ilçe ve belde...   tr      0

# %%
# tqdm.pandas('Translation progress')
outputs = imap_unordered_bar(translate, df[['comment_text', 'lang']].values)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
#  lang: it LANG:en
# 0it [00:00, ?it/s]
#  lang: tr LANG:en lang: tr LANG:en lang: tr LANG:en lang: es LANG:en lang: es LANG:en
#   2%|▏         | 1/51 [00:00<00:06,  7.64it/s]
#  lang: es LANG:en
#  lang: tr LANG:en
# 1it [00:00,  9.97it/s]
#  lang: es LANG:en lang: es LANG:en
#  lang: tr LANG:en lang: it LANG:en lang: es LANG:en lang: it LANG:en lang: tr LANG:en lang: es LANG:en lang: es LANG:en lang: es LANG:en lang: tr LANG:en lang: tr LANG:en lang: it LANG:en
#  lang: tr LANG:en lang: tr LANG:en lang: es LANG:en lang: it LANG:en lang: es LANG:en lang: es LANG:en lang: it LANG:en lang: tr LANG:en lang: es LANG:en lang: it LANG:en lang: tr LANG:en lang: it LANG:en lang: tr LANG:en lang: it LANG:en lang: it LANG:en lang: it LANG:en lang: tr LANG:en lang: it LANG:en lang: it LANG:en lang: es LANG:en
#   8%|▊         | 4/51 [00:00<00:02, 18.59it/s]
# 4it [00:00, 19.68it/s]
#  lang: es LANG:en lang: es LANG:en lang: tr LANG:en lang: es LANG:en lang: it LANG:en lang: tr LANG:en
#  lang: es LANG:en
# 51it [00:00, 170.97it/s]
#  lang: it LANG:en
# 100%|██████████| 51/51 [00:00<00:00, 152.09it/s]
#  lang: es LANG:en
#  lang: tr LANG:en

# %%
for i in range(len(outputs)):
    print('Original text:', outputs[i][0])
    print('Generated text:', outputs[i][1])
    print()
# Out:
# Original text: Este usuario ni siquiera llega al rango de    hereje   . Por lo tanto debería ser quemado en la barbacoa para purificar su alma y nuestro aparato digestivo mediante su ingestión.    Skipe linkin 22px   Honor, valor, leltad.      17:48 13 mar 2008 (UTC)
# Generated text: None
#
# Original text: Il testo di questa voce pare esser scopiazzato direttamente da qui. Immagino possano esserci problemi di copyright, nel fare cio .
# Generated text: None
#
# Original text: Vale. Sólo expongo mi pasado. Todo tiempo pasado fue mejor, ni mucho menos, yo no quisiera retroceder 31 años a nivel particular. Las volveria a pasar putas.Fernando
# Generated text: None
#
# Original text: Bu maddenin alt başlığı olarak  uluslararası ilişkiler  ile konuyu sürdürmek ile ilgili tereddütlerim var.Önerim siyaset bilimi ana başlığından sonra siyasal yaşam ve toplum, siyasal güç, siyasal çatışma, siyasal gruplar, çağdaş ideolojiler, din, siyasal değişme, kamuoyu, propaganda ve siyasal katılma temelinde çoğulcu siyasal sistemler.Bu alt başlıkların daha anlamlı olacağı kanaatindeyim.
# Generated text: None
#
# Original text: güzel, zaten kaynaklandırması zor subjektif kategoriler bunlar. bazı maddelerden çıkartmak, kiminden çıkartıp kiminde bırakmak, çıkartılanları yerine iade etmek yerine Kategori:Milletlere karşı ırkçı duygular dakilerin tamamına el atmak gerekiyor.    kibele
# Generated text: None
#
# Original text: No es mala idea. De hecho, yo estaba pensando descolgarme ya del reto mensual, pero esto vuelve a ilusionarme. El problema es que contabilizar los artículos a mano es muy tedioso, así que habría que disponer de una herramienta tipo escaladix que lo hiciera automáticamente. Y tampoco estaría mal disponer de resultados parciales cada tres meses o similar. Yo me apunto ) . Saludos de
# Generated text: None
#
# Original text: Belçika nın şehirlerinin yanında ilçe ve beldelerini yaparken sanırım Portekizi örnek alacaksın. Ben de uzak gelecekte(2-3 yıl) bu tip şeyler düşünüyorum. Tabii futbol maddelerinin hakkından geldikten sonra..    daha önce mesajlarınızı görmüştüm, hatta anon bölümünü bizzat kullanıyordum   sözünü anlamadım??  tanışmak bugüneymiş gibi bir şey eklemeyi düşündüm ama vazgeçtim. orayı da silmeyi unuttum. boşverin Kıdemli   +
# Generated text: None
#
# Original text: Creo que es importante que podamos reconocer a gente como Victor Manuel Vucetich , quien es originario de Tampico y ha sido 4 veces campeón del Futbol Mexicano , este último año con el Monterrey!!
# Generated text: None
#
# Original text: Ciao, in sintesi Ti dico questo, trovo sbagliato l eliminazione delle pagine che rimandano a quelle dell aiuto glossari, semplicemente perchè sono difficilmente  raggiungibili  da un utilizzatore che non sia esperto di Wiki, hai qualche soluzione in merito, perdonami e grazie. Pifoyde (msg)
# Generated text: None
#
# Original text: No sabemos quien es el autor del pie de imagen por ende no podemos acusarlo de haber inventado o no inventado la afirmacion, ergo no podemos decir que es investigacion original ya que no sabemos de donde obtuvo las lineas que escribió, lo que si sabemos es que la carga de la prueba recae sobre quien hace la afirmación, y en este caso es Xana la que afirma que el pie de imagen es subjetivo, pero, ¿segun quien?¿segun ella misma?, entonces en ese caso decir que el pie de iamgen es subjetivo es una afirmacion subjetiva de la propia subjetividad de Xana ya que no ha demostrado pruebas objetivas de que la susodicha sea realmente subjetiva, ergo eliminar tanto el pie de foto como la imagen misma nomás porque así lo dice la subjetividad de Xana, eso sería precisamente una edición subjetiva carente de argumentacion enciclopédica y por eso procedí a revertirla.Mr.
# Generated text: None
#
# Original text: Selam Merube. Şimdiye kadar gördüğüm en nazik, en kibar kullanıcıydın, hatta belki de -burada tanıyabildiğim kadarıyla elbet- tanıdığım en nazik insanlar arasındaydın. Ne oldu son bir kaç günde? Canın bir şeye mi sıkıldı? Birkaç lafa sinirlenip Vikipediye katkı yapmayı mı bırakacaksın?Rapsarbi diyeceğin mi vardı?  Merhaba rapsar. Nazik sözleriniz ve tanımlamalarınız için çok teşekkür ederim. Mesnetsiz iddialara maruz kalıp iftiraya uğrayan biri olarak böyle bir ortamda katkı yapmayı sorguluyorum. Şimdi de sadece bir haksızlığı farkettiğim için vikideyim. En azından uzunca bir süre daha buralarda olmayı düşünmüyorum. Kullanıcıları karalamak, zan altında bırakmak bu kadar kolayken de, vikiye neden döneyim ki diye de sormadan edemiyorum kendime. Tekrar çok teşekkür ederim. Sevgi ve saygılarımla    Merube 89        msj
# Generated text: None
#
# Original text:  He añadido la información que he podido encontrar acerca de los taxis colectivos. Quedo atento a cualquier comentario. Saludos y gracias. Farisori » 18:58 14 ene 2014 (UTC)
# Generated text: None
#
# Original text: Madde Demet Akalın maddesine aktarılmalı, başka sanatçı maddelerinde de diskografi kısmı ayrı madde olarak açılmamış, maddeye eklenmiştir.   KediÇobanı    İleti
# Generated text: None
#
# Original text: il buon senso non lo usate voi. siete voi i veri vandali prima o poi vi citeranno in giudizio...vi arrogate il diritto di cancellare ciò che non vi fa comodo, questo non lo si fa nelle democrazie ma solo nelle dittature. di questo passe metamedia vi distruggerà in breve tempo.
# Generated text: None
#
# Original text: Que tal Luicheto, he buscado un poco sobre la fecha de nacimiento de  Récord ; como bien mencionas, hay fuentes que ubican su nacimiento en 1896 como el libro del 95 aniversario del América y algunas de Televisa, sin embargo, también hay otras que lo ubican después, como Carlos Calderón o Héctor Hernández que mantienen que fue en 1904. Algo que también no me parece lógico es que estudiara en el Colegio Mascarones a los 20 años de edad y junto a por ejemplo Germán Núñez que se dice nació en 1903; o también la foto del equipo en 1916 donde me parece evidente que no tenía 20 años de edad. Si no crees adecuado que se ponga que tenía 13 años, te propongo que quitemos la frase  quien contaba con solo 20 años de edad  (que a su vez no me parece algo tan relevante) por lo menos en lo que pudieramos constatar más datos. Trataré de ponerme en contacto con Carlos Calderón y Héctor Hernández para ver si pudieran apoyarnos con más información. Saludos.
# Generated text: None
#
# Original text: Ma che cosa stai dicendo!??? Questa è la versione di novembre declinata al femminile e mutata al maschile solo dopo il tuo intervento qui! Come puoi notare nessuna bugia. Noto che la tua trollatura prosegue anche in inglese, nelle pagine utente e per e-mail. Avversariǿ (msg)
# Generated text: None
#
# Original text: La frase  agli esseri umani capaci e bendisposti ad ascoltare, ad imparare e a metterne in pratica gl insegnamenti  è POV, va bene pure correggere la frase da me inserita, ok, ma si può trovare una frase meno POV? Più terza e meno   confessionale . Per favore! -) WP non è una enciclopedia   confessionale  . Che palle doverlo ricordare ogni volta!!! Xinstalker (msg)
# Generated text: None
#
# Original text: No, invero mi riferivo a quella edita in proprio dal Patelli. PS: Sto aspettando dal Panconesi la nuova opera sugli ingegneri ferroviari italiani, son sicuro che me la gusterò...Ale Sasso (msg)
# Generated text: None
#
# Original text: El artículo de víctimas más generales esta hecho un desastre. No pueden fundirse.SanchoPanzaXXI Tu mensaje a la Insula de
# Generated text: None
#
# Original text: RAZZA DI IDIOTI!!! Vi siete bevuti il cervello???? Cos è questa intromissione????? Le vostre beghe personali risolvetele nelle vostre pagine (personali)! In più, io ho votato per la cancellazione!!! Quindi andate a .....lo!
# Generated text: None
#
# Original text: Coincido. Lo de Feinmann ni siquiera es periodismo, es apenas el ejercicio torpe de un vocero inconsistente de los sectores infames que le abonan el sueldo.
# Generated text: None
#
# Original text: Selamlar. Vallaha kaynamış yav...  Yer Fener Gök Cimbom  adlı FB-GS ezeli rekabeti anlatan bir kitap var sadece... Ancak piyasada çeşitli kitaplar bulabilirsin. En bilineni İnkılap Yayınevi nden çıkan futbolla ilgili kitaplar... Bu arada Shilton ı sana ithaf ediyorum  Mrb. Mahtumkulu Firaki maddesi de telifli içerikten oluşuyor. HS şablonu kaldırıldığı için direk size yazmak istedim, kolay gelsin...Rapsar  Merhaba, madde silindi. Kullanıcıya telif için bir uyarı şablonu gönderdim. Kolay gelsin...Vikiçizer
# Generated text: None
#
# Original text: Hola, a Torneo WTA de Barcelona también le iría bien una fuente, saludos, Poco a poco...¡adelante! 21:36 5 jun 2009 (UTC)
# Generated text: None
#
# Original text: /* Comentarios al respecto *\ Las únicas locomotoras que posee FGV son 4: { 3 Alsthom situadas en Alacant, y 1 Naval-Rolls Roice situado en València-sud). NO
# Generated text: None
#
# Original text: Buenas tardes, MONUMENTA. He creado la página del pintor Victorio Manchón, pero ahora no se situarla en la web. Cuando puedas, me dices cómo hacerlo. Gracias.
# Generated text: None
#
# Original text: (Koca bir mesajım nereye gitti yahu?  Mesajların çatışması  tamam da o metin nerde şimdi? Neyse ki arif olan başlıktan neler yazdığımı anlıyacaktır. - Hasan Sami
# Generated text: None
#
# Original text: Hola, veo que pusiste un aviso de  wikificar  en este artículo; pero me rompo la cabeza y no veo a qué te refieres.
# Generated text: None
#
# Original text: Pornokrasi başlığına linklenmeli. Gerçi bu sapık maddeyi daha bilimsel olarak ele alıp eleştiren bir yazı asılmalıydı.95.7.150.45
# Generated text: None
#
# Original text:  VİKİPEDİDEKİ DARBEYE VE İSİM DEĞİŞİKLİĞİNİN Kişisel olup olmadığına yetkili birimler karar vermelidir, ayrıca vikipedi darbe yapılan yer değildir. 5 kuralı İHLAL EDENLERİ ŞİKAYET EDİYORUM
# Generated text: None
#
# Original text: ti fa così schifo lasciare il doppio spazio?Mpiz (msg)  ah, inveve è proprio bello avere tutti i paragrafi appiccicati che non si capisce nemmeno dove inizia uno e finisce l altro..si si proprio belloMpiz (msg)  si ma le linee cosi sono tutte appiccicate e non si capisce una beneamata. col doppio spazio rimanendo leggermente piu distanziate, anche a colpo d occhio vedi dove finisce uno ed inizia il successivo.Mpiz (msg)
# Generated text: None
#
# Original text: Cuestiono la imparcialidad o neutralidad de este artículo, parece escrito por un falangista. ¿Acaso se imagina alguien un articulo sobre el Nazismo escrito por un Nazi? De la misma manera, este artículo me parece de dudosa objetividad.
# Generated text: None
#
# Original text: Ciao, ho notato il tuo  fix corposo  effettuato alla voce Torano_di_Borgorose, grazie. Volevo chiederti come mai ha tolto la festa patronale del 15 agosto (Santa Maria Assunta) altrettanto importante come quella che hai lasciato. Volevo anche farti notare che nella sezione  Riferimenti  il link esterno che hai aggiunto riporta una dicitura inesatta in quanto la pagina esterna parla prevalentemente del martirio di Santa Anatolia e non solo di Sant Audace come da te riportato. Non so se procedere con la modifica o se ci pensi tu... fammi sapere. Ciao e grazie per l interessamento alla voce del mio paese.
# Generated text: None
#
# Original text: Qué libros son distintos?  Descubrimiento y conquista catalana de América. Una historia reescrita por los castellanos  es un solo libro, de Enric Guillot.
# Generated text: None
#
# Original text: Hola De verdad pensaste, que no te iba a encontrar?, te lo dije, te estoy rastreando, estoy rastreando tus comentarios, tus insultos y tus lloriqueos, pronto sabrás de mi.
# Generated text: None
#
# Original text: Hola: Ya he hecho la gran mayoría de las correcciones que solicitabas. Fíjate si quieres hacer tú alguna otra que veas conveniente. Sería una pena que se le quite el rótulo al artículo, que tan completo y neutral ha quedado. Te pediría que le des un vistazo ahora y lo veas, y si te parece, puedes cambiar de opinión en la votación. Saludos, Lancha
# Generated text: None
#
# Original text:  Ringrazio te per la cortese risposta (e sono contento che tu abbia trovato le modifiche accettabili), la precisazione e il valido suggerimento per il futuro. Ciao! AgenteMulder (msg)
# Generated text: None
#
# Original text: Merhaba BSRF, bir maddeye ekleyeceğim bilgiyle ilgili kaynak eklemem gerek ancak yazılı bir kaynak bulamadım. YouTube tan bir videoyu kaynak göstermek gibi bir şey söz konusu olabilir mi acaba? Görkem7 mesaj
# Generated text: None
#
# Original text: Ciao, le sandbox servono per preparare con calma le voci di argomento enciclopedico, cosa che non può certo essere un partito nato   ieri  . Buon lavoro! Sanremofilo (msg)
# Generated text: None
#
# Original text: In riguardo a cio  che ho pubblicato e tu hai già tolto dai maroni. Lo trovo ingiusto e un po  comunista. sei pregato di non scassarmi il cazzo, e te lo chiedo gentilemnte.
# Generated text: None
#
# Original text: La voce è di fatto agiografica, visto che la voce ignora clamorosamente il chiaro declino che ha subito la carriera di Lady Gaga, declino che è sotto gli occhi di tutti, non solo di vendite di album (dai 21 di The Fame, agli 8 di Born This Way per finire ai 2 di Artpop) ma anche mediaticamente parlando non se la fila più nessuno da alcuni anni. E prima che mi si accusi di  ricerca originale  riguardo al declino: What happen to Lady Gaga ? (NY Post) Lady Gaga needs ‘American Horror Story’ more than it needs her (Washington Post) La lenta e dolorosa discesa agli inferi di Lady Gaga (Vice) Lady Gaga Was The Biggest Pop Star In The World. What Happened? (Huffington post) Ladi Gaga in caudta libera (gay.it) QUI lo stesso Akon ammette di aver abbandonato Lady Gaga prevedendone il declino 151.67.198.
# Generated text: None
#
# Original text: Günaydın ) Daha sonra tekrar incelediğimde durumu hallettim, sonuç başarılı. Şu sıralar okuma yapmak için vaktim var. Eğer önceki mesajımda bahsettiğim sayfaya link bırakırsan, gereken bilgilere senin için ulaşabilirim, s
# Generated text: None
#
# Original text: Es que los articulos de danza no son lo mio y para colmo suelen confundirse con articulos sobre musica, voy a hacer como decis si no estoy seguro trato de preguntar, Pense que  bailecito  figuraba dentro de los estilos de musica de Bolivia en su respectivo articulo (que por cierto no tiene ninguna referencia y la redaccion estaba fea antes que la corrigiese). El origen uruguayo del coñac mas vale dejarlo pasar, por mas que referencias sobran que lo afirman. Lo que nunca voy a saber es porque nunca me has permitido categorizar Paso de los Toros como bebida uruguaya, algun dia lo sabré.
# Generated text: None
#
# Original text: Bu şiir en az 25 yıllık, kitabın yanında basım tarihi 1991 yazıyor? Bir hata mı var acaba? Levent Abi
# Generated text: None
#
# Original text: Tekrar merhaba. Bahse konu internet sitesinin maddesindeki reklam kokan üslubu değiştirseniz dahi, maddede bahse konu edilen internet sitesi, kayda değerlik kriterlerini karşılamadığı için, ansiklopedik bir üslup kullanılmış dahi olsa, M6 kriteri uyarınca silinecektir. İyi çalışmalar. Utku Tanrıveremesaj
# Generated text: None
#
# Original text: Eh mi scusi, ma Lei è proprio un comunista e illiberale, con tutte queste cancellazioni!    SERGIUS    (CATUS NIGER)
# Generated text: None
#
# Original text: Levent Abi nasılsın? Hayat nasıl gidiyor? Umarım her şey istediğin gibidir. Bu arada Janet Jackson maddesi seçkin madde oldu. Çok çalışmıştım, insanın emeğinin karşılığını alması çok güzel. Kendine çok iyi bak Levent Abi. İyi çalışmalar. ♪♫     A  takan      0652   |   mesaj
# Generated text: None
#
# Original text: İfadem biraz sert olduysa kusura bakma. Doğrusu Descartes da o yüzden imla hatası diye değiştirip yanlışını girmem garibime gitti de... Mskyrider
# Generated text: None
#
# Original text: Kod hatalarını düzeltmişsiniz,elinize sağlık çok teşekkürler.Önceki sürümleri araştırdım.13 Haziran 2010 da Kullanıcı:Türk Süvarisi nin yaptığı şu değişikliğe kadar 107 kaynak var ve benim görebildiğim kadarıyla kaynaklarda hata yok.Türk Süvarisi nin değişikliğinden sonra kaynak sayısı 111 e çıkıyor ve kaynak hataları oluşuyor.Bana Türk Süvarisi hatalı bir şekilde yeni kaynaklar eklemiş gibi geldi.Siz ne dersiniz?Yardımcı olursanız çok sevinirim.Bu arada İran ı KM adayı göstermeyi düşünüyorum ve bu nedenle maddeyi düzenlemeye çalışıyorum.Vikipedi:Madde incelemesi/İran/arşiv1 de siz de görüşlerinizi belirtirseniz maddenin gelişimi adına katkısı olur diye düşünüyorum.İngiltere Portalı nda sizin ve diğer vikipedistlerin bahsettiği yorumsal ifadeleri ve yazım hatalarını düzelttim.İsterseniz portala tekrar göz atın.Sevgiler, iyivikiler   Âkhilleus       mesaj
# Generated text: None
#
# Original text: Nihilo sigue empeñado en calificar a García Oliver de líder. Rogaría que nos de una explicación, ya que etiquetar a un anarquista de  líder  es harto ridículo, si se me permite la expresión... García
# Generated text: None
#
# Original text: Tamam bundan sonra direk resme bağlantı vereceğim. Ancak verdiğim linkteki dosya genellikle jpg formatında oluyor ve transparanlanmamış. Bu yüzden o linkteki dosya da farklı gözükecektir. Ben yine belirtteyim de:) İyi çalışmalar...    insan|perver
# Generated text: None
#
# Original text: Beh, anche io, se per quello, mi considero prima europeo, italiano, sardo e poi cagliaritano (cit.). Ciò nonostante, vivo a Casteddu da sempre! Non per farmi i ca**i tuoi, ma la tua risposta mista alla tua pagina utente (da cui evinco che hai la mia età (31) o più, ma non direi meno) mi ha incuriosito parecchio. A ciò aggiungi il fatto che Cagliari non è, che so, Cremona, dove qualunque persona del nord può veramente  bazzicare , magari sbagliando uscita dell A1. Se vieni qua la prima volta, non essendoci nato o non avendoci parenti, è per un motivo preciso (principalmente vacanze, lavoro, rapporti personali/sentimentali), anche se poi conosco tanta gente che non è riuscita a staccarsi per molto tempo (cit.). Ad ogni modo, mi piacerebbe sapere qual è il tuo motivo. Al tempo stesso, sei ovviamente liberissimo di dirmi di farmi i cavoli miei! Ciao,    KS   «...»
# Generated text: None

# %% [markdown]
# ## Libraries that already implement back translation:
#
# Fortunately, back translation is already implemented in some libraries written in Python.
# For example, textaugment is one of these libraries. Let's try it!!!

# %%
! pip install textaugment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textaugment
#   Downloading textaugment-1.3.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from textaugment) (3.7)
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (from textaugment) (0.15.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from textaugment) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from textaugment) (1.21.6)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->textaugment) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim->textaugment) (1.7.3)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->textaugment) (5.2.1)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.7 MB/s
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans->textaugment) (2022.9.24)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans->textaugment) (3.0.4)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Collecting hstspreload
#   Downloading hstspreload-2022.11.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 16.7 MB/s
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans->textaugment) (2.10)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 4.1 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.7 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->textaugment) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk->textaugment) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->textaugment) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk->textaugment) (2022.6.2)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=90414367380657914199bd75582224ac8da5608e507b2f2a932410b0c0ffa5d7
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans, textaugment
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2022.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.3.0 textaugment-1.3.4

# %%
from textaugment import Translate
SRC = "en" # source language of the sentence
TO = "es" # target language


texts = ["John is going to town",   
         "I want to be a computer engineer.",
         "It usually rains everyday here",
         "I am so mad at her.",
         'I do love my pets',
         'I have no money at the moment'
    ]
t = Translate(src=SRC, to=TO)
for text in texts:
    print('original text:', text)
    print('augmented text:', t.augment(text))
    print()
# Out:
# original text: John is going to town
# augmented text: john goes to the city
#
# original text: I want to be a computer engineer.
# augmented text: i want to be computer engineer.
#
# original text: It usually rains everyday here
# augmented text: usually, it rains every day here
#
# original text: I am so mad at her.
# augmented text: i am so angry with her.
#
# original text: I do love my pets
# augmented text: i love my pets
#
# original text: I have no money at the moment
# augmented text: i don't have money right now
